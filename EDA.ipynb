# %% [markdown]
# Hypothesis:
#
# i. Is there any seasonality in number of customers using the cab service
# ii. Which company has maximum cab users at a particular time period?
# iii. Does margin proportionally increase with increase in number of customers
# iv. What are the attributes of these customer segments?

# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline 
from geopy.distance import great_circle

# %% [markdown]
# Understand the field names and data types

# %%
# Reading the Dataset
cab_data = pd.read_csv("./Cab_Data.csv")

city_data = pd.read_csv("./City.csv")

CustomerID_data = pd.read_csv("./Customer_ID.csv")

TransactionID_data = pd.read_csv("./Transaction_ID.csv")

# %%
cab_data.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
# 5        10000016           42376  Pink Cab  ATLANTA GA          6.06
# 6        10000017           42372  Pink Cab   AUSTIN TX         44.00
# 7        10000018           42376  Pink Cab   AUSTIN TX         35.65
# 8        10000019           42381  Pink Cab   BOSTON MA         14.40
# 9        10000020           42375  Pink Cab   BOSTON MA         10.89
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
# ...

# %%
cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
city_data
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city_data.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
CustomerID_data.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
CustomerID_data.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
TransactionID_data.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
TransactionID_data.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
print("cab_data shape", cab_data.shape)
print("city_data shape", city_data.shape)
print("CustomerID_data shape", CustomerID_data.shape)
print("TransactionID_data shape", TransactionID_data.shape)
# Out:
# cab_data shape (359392, 7)
# city_data shape (20, 3)
# CustomerID_data shape (49171, 4)
# TransactionID_data shape (440098, 3)

# %%
print("Cab_data \n\n", cab_data.dtypes)
# Out:
# Cab_data
#
#  Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
print("City_data \n\n", city_data.dtypes)
# Out:
# City_data
#
#  City          object
# Population    object
# Users         object
# dtype: object

# %%
print("CustomerID_data \n\n", CustomerID_data.dtypes)
# Out:
# CustomerID_data
#
#  Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
print("TransactionID_data\n\n", TransactionID_data.dtypes)
# Out:
# TransactionID_data
#
#  Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %% [markdown]
# Merge Cab_data dataframes and TransactionID dataframe by Transaction_ID number

# %%
Cab_TranactionID = pd.merge(cab_data, TransactionID_data, on="Transaction ID")

# %%
Cab_TranactionID.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode
# 0         370.95       313.635        29290         Card
# 1         358.52       334.854        27703         Card
# 2         125.20        97.632        28712         Cash
# 3         377.40       351.602        28020         Cash
# 4         114.62        97.776        27182         Card

# %%
Cab_TranactionID.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
Cab_Tranaction_CustomerID_data= pd.merge(Cab_TranactionID , CustomerID_data, on="Customer ID")            #

# %%
Cab_Tranaction_CustomerID_data.head()
# Out:
#    Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0        10000011           42377    Pink Cab  ATLANTA GA         30.45
# 1        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 2        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 3        10000012           42375    Pink Cab  ATLANTA GA         28.62
# 4        10320494           43211  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    Income (USD/Month)
# 0               10813
# 1               10813
# 2               10813
# 3                9237
# ...

# %%
data= pd.merge(Cab_Tranaction_CustomerID_data , city_data, on="City")

# %%
data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10351127           43302  Yellow Cab     ATLANTA GA
# 2             10412921           43427  Yellow Cab     ATLANTA GA
# 3             10000012           42375    Pink Cab     ATLANTA GA
# 4             10320494           43211  Yellow Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10307228           43162  Yellow Cab  WASHINGTON DC
# 359388        10319775           43203  Yellow Cab  WASHINGTON DC
# 359389        10347676           43287  Yellow Cab  WASHINGTON DC
# 359390        10358624           43314  Yellow Cab  WASHINGTON DC
# 359391        10370709           43342  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# ...
